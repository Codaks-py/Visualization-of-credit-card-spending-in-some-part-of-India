# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %matplotlib inline

# %%
df1 = pd.read_csv('Credit card transactions - India - SImple.csv', parse_dates=True)
df1
# Out:
#        index                   City       Date  Card Type Exp Type Gender  \
# 0          0           Delhi, India  29-Oct-14       Gold    Bills      F
# 1          1  Greater Mumbai, India  22-Aug-14   Platinum    Bills      F
# 2          2       Bengaluru, India  27-Aug-14     Silver    Bills      F
# 3          3  Greater Mumbai, India  12-Apr-14  Signature    Bills      F
# 4          4       Bengaluru, India   5-May-15       Gold    Bills      F
# ...      ...                    ...        ...        ...      ...    ...
# 26047  26047         Kolkata, India  22-Jun-14     Silver   Travel      F
# 26048  26048            Pune, India   3-Aug-14  Signature   Travel      M
# 26049  26049       Hyderabad, India  16-Jan-15     Silver   Travel      M
# 26050  26050          Kanpur, India  14-Sep-14     Silver   Travel      M
# 26051  26051       Hyderabad, India  19-Oct-13  Signature    Bills      M
#
#        Amount
# 0       82475
# 1       32555
# 2      101738
# 3      123424
# ...

# %% [markdown]
# <i>Then i removed the duplicates from the date Columns to have a better dataset to analyse

# %%
df = df1.drop_duplicates('Date')
df
# Out:
#       index                   City       Date  Card Type       Exp Type  \
# 0         0           Delhi, India  29-Oct-14       Gold          Bills
# 1         1  Greater Mumbai, India  22-Aug-14   Platinum          Bills
# 2         2       Bengaluru, India  27-Aug-14     Silver          Bills
# 3         3  Greater Mumbai, India  12-Apr-14  Signature          Bills
# 4         4       Bengaluru, India   5-May-15       Gold          Bills
# ...     ...                    ...        ...        ...            ...
# 3204   3204       Ahmedabad, India  13-Dec-14  Signature          Bills
# 3282   3282       Ahmedabad, India  22-Mar-15  Signature          Bills
# 3541   3541           Delhi, India  25-Jan-14  Signature  Entertainment
# 3725   3725  Greater Mumbai, India   9-May-14       Gold           Fuel
# 4638   4638       Bengaluru, India  10-Jul-14     Silver  Entertainment
#
#      Gender  Amount
# 0         F   82475
# 1         F   32555
# 2         F  101738
# ...

# %% [markdown]
# <i> After removing the duplicates from date, i removed the index column cos it wasn't needed.

# %%
del df['index']

# %%
df.head(10)
# Out:
#                     City       Date  Card Type Exp Type Gender  Amount
# 0           Delhi, India  29-Oct-14       Gold    Bills      F   82475
# 1  Greater Mumbai, India  22-Aug-14   Platinum    Bills      F   32555
# 2       Bengaluru, India  27-Aug-14     Silver    Bills      F  101738
# 3  Greater Mumbai, India  12-Apr-14  Signature    Bills      F  123424
# 4       Bengaluru, India   5-May-15       Gold    Bills      F  171574
# 5           Delhi, India   8-Sep-14     Silver    Bills      F  100036
# 6           Delhi, India  24-Feb-15       Gold    Bills      F  143250
# 7  Greater Mumbai, India  26-Jun-14   Platinum    Bills      F  150980
# 8           Delhi, India  28-Mar-14     Silver    Bills      F  192247
# 9           Delhi, India   1-Sep-14   Platinum    Bills      F   67932

# %%
df = df.sort_values(by = ['City', 'Gender'])
df.head(20)
# Out:
#                  City       Date  Card Type Exp Type Gender  Amount
# 23   Ahmedabad, India  11-Oct-13       Gold    Bills      F  668568
# 24   Ahmedabad, India  26-Mar-14       Gold    Bills      F  339112
# 32   Ahmedabad, India  24-Nov-13   Platinum    Bills      F  227702
# 33   Ahmedabad, India   8-Nov-14       Gold    Bills      F  864090
# 34   Ahmedabad, India   6-Sep-14  Signature    Bills      F  440605
# 35   Ahmedabad, India  24-Mar-15   Platinum    Bills      F  954660
# 36   Ahmedabad, India   1-Jan-14  Signature    Bills      F  255577
# 37   Ahmedabad, India  12-Jul-14     Silver    Bills      F  337352
# 38   Ahmedabad, India   4-Feb-14   Platinum    Bills      F  660244
# 46   Ahmedabad, India  10-Dec-13       Gold    Bills      F  892016
# 47   Ahmedabad, India   4-Nov-13   Platinum    Bills      F  313626
# 52   Ahmedabad, India  21-Dec-13  Signature    Bills      F  402300
# 56   Ahmedabad, India  28-Jan-15  Signature    Bills      F  326283
# ...

# %%
del df['Date']

# %%
df.head()
# Out:
#                 City  Card Type Exp Type Gender  Amount
# 23  Ahmedabad, India       Gold    Bills      F  668568
# 24  Ahmedabad, India       Gold    Bills      F  339112
# 32  Ahmedabad, India   Platinum    Bills      F  227702
# 33  Ahmedabad, India       Gold    Bills      F  864090
# 34  Ahmedabad, India  Signature    Bills      F  440605

# %%
df.City.unique()
# Out:
# array(['Ahmedabad, India', 'Bengaluru, India', 'Delhi, India',
#        'Greater Mumbai, India'], dtype=object)

# %%
df.shape
# Out:
# (600, 5)

# %%
df.City.value_counts()
# Out:
# Greater Mumbai, India    165
# Delhi, India             149
# Bengaluru, India         144
# Ahmedabad, India         142
# Name: City, dtype: int64

# %%
df.describe()
# Out:
#               Amount
# count     600.000000
# mean   330009.341667
# std    266939.562604
# min      2138.000000
# 25%    130896.000000
# 50%    253898.500000
# 75%    483532.750000
# max    998077.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 600 entries, 23 to 3725
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   City       600 non-null    object
#  1   Card Type  600 non-null    object
#  2   Exp Type   600 non-null    object
#  3   Gender     600 non-null    object
#  4   Amount     600 non-null    int64
# dtypes: int64(1), object(4)
# memory usage: 28.1+ KB

# %% [markdown]
# <b><i>Females spends more

# %%
df.Gender.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
df=df.rename(
    columns={
        'Exp Type' : 'Exp_Type',
        'Card Type' : 'Card_Type'
    }
)

# %% [markdown]
# <b>Greater Mumbai, India records more spending than other cities

# %%
df.City.value_counts().plot(kind='barh', figsize=(10,5), title='List of City in India with highest Transaction'
)
# Out:
# <AxesSubplot: title={'center': 'List of City in India with highest Transaction'}>

# %% [markdown]
# <b><i> We can deduce by city what individuals spend spend their money on using different card,
# <i>And also people spend more on bills

# %%
df[
    df.City.isin([
        'Greater Mumbai, India', 'Delhi, India', 'Bengaluru, India', 'Ahmedabad, India'
    ])
].groupby(
    ['City', 'Card_Type']
).Exp_Type.value_counts().unstack().plot.bar(
    title =' Cities with  Card Types For Transactions and how they spend their money', figsize = (20, 5)
)
# Out:
# <AxesSubplot: title={'center': ' Cities with  Card Types For Transactions and how they spend their money'}, xlabel='City,Card_Type'>

# %% [markdown]
# <i><b>We can dedudes that Females dominates in all card type and cities

# %%
df[
    df.City.isin([
        'Greater Mumbai, India', 'Delhi, India', 'Bengaluru, India', 'Ahmedabad, India'
    ])
].groupby(
    ['City', 'Card_Type']
).Gender.value_counts().unstack().plot.bar(
    title =' Genders with Highest Card Types For Transactions Per Cities', figsize = (20, 5)
)
# Out:
# <AxesSubplot: title={'center': ' Genders with Highest Card Types For Transactions Per Cities'}, xlabel='City,Card_Type'>

# %% [markdown]
# <i><b> We can Agree That People hold more of Silver Card than the rest in these cities

# %%
df[
    df.City.isin([
        'Greater Mumbai, India', 'Delhi, India', 'Bengaluru, India', 'Ahmedabad, India'
    ])
].groupby(
    ['City', 'Card_Type']
).Card_Type.value_counts().unstack().plot.bar(
    title =' Showing The level of Card type in each City', figsize = (20, 5)
)
# Out:
# <AxesSubplot: title={'center': ' Showing The level of Card type in each City'}, xlabel='City,Card_Type'>

# %% [markdown]
# <i><b>Showing the total in figures spent by each genders

# %%
a = df[df.Gender == 'F']
c = a['Amount'].sum()
b = df[df.Gender == 'M']
d = b['Amount'].sum()

print(f'Female Spending: {c}\nMale Spending: {d}')
# Out:
# Female Spending: 192442625
# Male Spending: 5562980
